# %% [markdown]
# # Ejercicios de probabilidad

# %% [markdown]
# ## Ejercicio 1
#
# Dos dados se lanzan una vez y se observa el total obtenido. Usa una simulación para encontrar la probabilidad estimada de que la puntuación sea mayor a 7 o un número par. Una simulación es una repetición del mismo experimento multiples veces para observar su comportamiento:
#
# - Ejecuta el experimento 1000 veces (lanza 2 dados 1000 veces, y suma el número de ambos dados).
# - Lleva ua cuenta de los números y las veces que la suma fue mayor a 7 o un número par.
# - Divide el número del paso 2 entre el número de iteraciones(1000).

# %%
# TODO
import numpy as np
import random
import pandas as pd

dado1 = [1,2,3,4,5,6]
dado2 = [1,2,3,4,5,6]
def lanzar_dado (n=1000):
    count = 0
    for i in range(n):

        d1 = np.random.choice(dado1)
        d2 = np.random.choice(dado2)
        x = d1 + d2
        #print(i)
        
        if x > 7 or x%2 ==0:
            count+=1  
            
    prob = (count/n) *100   
    return f'dado 1 = {d1} y dado 2 = {d2} and our conditions were met {count} times,\n giving us a probability of them being met of {prob}% '


print(lanzar_dado())
# Out:
# dado 1 = 3 y dado 2 = 1 and our conditions were met 654 times,
#  giving us a probability of them being met of 65.4%

# %% [markdown]
# ## Ejercicio 2
#
# Una caja contiene 10 bolas blancas, 20 bolas rojas y 30 bolas verdes. Si tomamos 5 bolas de la caja reemplazándolas (tomando una bola, anotando el color y luego regresandola a la caja). Queremos saber la probabilidad de:
#
# 1. Tomar 3 blancas y 2 rojas.
# 2. Toas todas del mismo color.
#
# Ejecuta el experimento 1000 veces y calcula las probabilidades que mencionadas.

# %%
ball_box = {}

# Crea la cajas con las bolas
for i in range(60):
    if i < 10:
        ball_box[i] = "White"
    elif (i > 9) and (i < 30):
        ball_box[i] = "Red"
    else:
        ball_box[i] = "Green"

print(ball_box)
print(type(ball_box) )       
# TODO
# Out:
# {0: 'White', 1: 'White', 2: 'White', 3: 'White', 4: 'White', 5: 'White', 6: 'White', 7: 'White', 8: 'White', 9: 'White', 10: 'Red', 11: 'Red', 12: 'Red', 13: 'Red', 14: 'Red', 15: 'Red', 16: 'Red', 17: 'Red', 18: 'Red', 19: 'Red', 20: 'Red', 21: 'Red', 22: 'Red', 23: 'Red', 24: 'Red', 25: 'Red', 26: 'Red', 27: 'Red', 28: 'Red', 29: 'Red', 30: 'Green', 31: 'Green', 32: 'Green', 33: 'Green', 34: 'Green', 35: 'Green', 36: 'Green', 37: 'Green', 38: 'Green', 39: 'Green', 40: 'Green', 41: 'Green', 42: 'Green', 43: 'Green', 44: 'Green', 45: 'Green', 46: 'Green', 47: 'Green', 48: 'Green', 49: 'Green', 50: 'Green', 51: 'Green', 52: 'Green', 53: 'Green', 54: 'Green', 55: 'Green', 56: 'Green', 57: 'Green', 58: 'Green', 59: 'Green'}
# <class 'dict'>

# %%
n = input(int)
def take5_ball(n = 1000):
    exp1 = 0
    exp2 = 0
    for i in range(n):
        balls=[]
        for i in range(5):
            balls.append(random.choice(list(ball_box.values())))
        balls = np.array(balls)
        global white 
        white = sum(balls == 'White')
        global red 
        red = sum(balls == 'Red')
        global green 
        green = sum(balls == 'Green')
        if (white == 3) and (red == 2):
            exp1+= 1
        if (white == 5) or (red == 5) or (green ==5):
                exp2 += 1
    prob_1 = exp1/n * 100
    prob_2 = exp2/n * 100
    return print(f'La probabilidad de tomar 3 blancas y 2 rojas es de {prob_1}% \n y la probabilidad de sacar todas del mismo color es de {prob_2}%')
take5_ball()

# %% [markdown]
# """
# Tenemos que:
# Crear un contador/acumulador donde se agregue nuestra bola una por una hasta ser 5
# hacer una funcion que tome una bola y la devuelva.
# al tomar la bola tenemos que agregar una igual, al devolverla, podemos solo seleccionar la bola sin sacarla
# hacemos un for loop que utilice un random para seleccionar la bola.
# las probabilidades las obtenemos utilizando condicionales
# #####
# Vamos a crear un loop random para seleccionar 5 numeros del 0 al 60 y con ello vamos
# a asignar el resultado a una llamada de valor de dict con indice
# Despues agregamos ese valor a un list que es el resultado
# Ya que tenemos eso loopeamos para 1000 veces y usamos ifs para crear un contador que
# aumente uno cada vez que la condicion se cumple
#
# """
